# %%
import unicodedata
import re
import os
import json
from tqdm import tqdm
import random
from pprint import pprint

# %%
data_home = "../ori_data"

# %% [markdown]
# # WebNLG

# %%
data_dir = os.path.join(data_home, "webnlg")
train_data_path = os.path.join(data_dir, "train_data.json")
valid_data_path = os.path.join(data_dir, "valid_data.json")
test_data_path = os.path.join(data_dir, "test_data", "test.json")

# %%
train_data = json.load(open(train_data_path, "r", encoding = "utf-8"))
valid_data = json.load(open(valid_data_path, "r", encoding = "utf-8"))
test_data = json.load(open(test_data_path, "r", encoding = "utf-8"))

# %%
# bad_samples = []
# for sample in train_data + valid_data + test_data:
#      for spo in sample["spo_list"]:
#         if spo[0] == "``" or spo[2] == "``":
#             bad_samples.append(bad_samples)
#             print(" ".join(sample["tokens"]))
#             pprint(sample["spo_list"])
# Out:
# Verona , Italy is the home to A.C. Chievo Verona which has 39371 members and the full name of `` Associazione Calcio ChievoVerona S.r.l . `` .
# [['A.C. Chievo Verona',
#   'fullname',
#   '`` Associazione Calcio ChievoVerona S.r.l . ``'],
#  ['A.C. Chievo Verona', 'ground', '``'],
#  ['A.C. Chievo Verona', 'numberOfMembers', '39371']]
# A.D. Isidro Metapan 's full name is `` Asociación Deportiva '' . They have 10000 members and their ground is in Metapan , El Salvador .
# [['A.D. Isidro', 'ground', '``'],
#  ['A.D. Isidro', 'numberOfMembers', '10000'],
#  ['A.D. Isidro', 'fullname', "`` Asociación Deportiva ''"]]
# A.F.C . Blackpool fullname is `` Association Football Club Blackpool , '' they have 1500 members and their grounds are at Jespon Way .
# [['A.F.C . Blackpool', 'ground', '``'],
#  ['A.F.C . Blackpool', 'numberOfMembers', '1500'],
#  ['A.F.C . Blackpool', 'fullname', '`` Association Football Club Blackpool']]
# A.F.C . Blackpool fullname is `` Association Football Club Blackpool '' . They have 1500 members and their ground is The Mechanics .
# [['A.F.C . Blackpool', 'ground', '``'],
#  ['A.F.C . Blackpool', 'numberOfMembers', '1500'],
#  ['A.F.C . Blackpool', 'fullname', "`` Association Football Club Blackpool ''"]]
# A.F.C . Fylde 's ground is Kellamergh Park . They have 3180 members and the full name of `` Association Football Club Fylde . `` .
# [['A.F.C . Fylde', 'ground', '``'],
#  ['A.F.C . Fylde', 'numberOfMembers', '3180'],
#  ['A.F.C . Fylde', 'fullname', '`` Association Football Club Fylde']]
# The full name of the A.F.C . Fylde is `` Association Football Club Fylde '' they are based at Bryning Lane and have 3180 members .
# [['A.F.C . Fylde', 'numberOfMembers', '3180'],
#  ['A.F.C . Fylde', 'fullname', "`` Association Football Club Fylde ''"],
#  ['A.F.C . Fylde', 'ground', '``']]
# The nickname of Agremiação Sportiva Arapiraquense is `` Alvinegro '' , they played in 2015 and they have 17,000 members .
# [['Agremiação Sportiva Arapiraquense', 'nickname', '``'],
#  ['Agremiação Sportiva Arapiraquense', 'season', '2015']]
# Ayam penyet is a food found in Java and can be found nationwide and also in Malaysia and Singapore . `` Squeezed '' or `` smashed '' fried chicken served with sambal is a main ingredient in ayam penyet .
# [['Ayam penyet', 'region', '``'],
#  ['Ayam penyet', 'country', 'Java'],
#  ['Ayam penyet',
#   'mainIngredients',
#   "`` Squeezed '' or `` smashed '' fried chicken served with sambal"]]
# Ayam penyet is from Indonesia and can be found nationwide and also in Malaysia and Singapore . The main ingredients of Ayam penyet are `` squeezed '' or `` smashed '' chicken served with sambal .
# [['Ayam penyet', 'region', '``'],
#  ['Ayam penyet', 'mainIngredients', '``'],
#  ['Ayam penyet', 'country', 'Indonesia']]
# Ayam penyet is from Indonesia and can be found nationwide and also in Malaysia and Singapore . The main ingredients of Ayam penyet are `` squeezed '' or `` smashed '' chicken served with sambal .
# [['Ayam penyet', 'region', '``'],
#  ['Ayam penyet', 'mainIngredients', '``'],
#  ['Ayam penyet', 'country', 'Indonesia']]
# Ayam penyet is a dish from the region of Singapore as well as from Java . The main ingredients of Ayam penyet are `` squeezed '' or `` smashed '' chicken served with sambal .
# [['Ayam penyet', 'region', 'Singapore'],
#  ['Ayam penyet', 'country', 'Java'],
#  ['Ayam penyet', 'mainIngredients', '``']]
# 1634 : The Bavarian Crisis written by Virginia DeMarce is available in print form and can be located by it 's ISBN number `` 978-1-4165-4253-7 '' .
# [['1634 : The Bavarian Crisis', 'ISBN_number', "`` 978-1-4165-4253-7 ''"],
#  ['1634 : The Bavarian Crisis', 'mediaType', '``'],
#  ['1634 : The Bavarian Crisis', 'author', 'Virginia DeMarce']]
# 1634 : The Bavarian Crisis can be located by it 's ISBN number `` 978-1-4165-4253-7 '' , its author is Eric Flint and was put in print .
# [['1634 : The Bavarian Crisis', 'author', 'Eric Flint'],
#  ['1634 : The Bavarian Crisis', 'ISBN_number', "`` 978-1-4165-4253-7 ''"],
#  ['1634 : The Bavarian Crisis', 'mediaType', '``']]
# `` 1634 ; The Ram Rebellion '' by Eric Flint is available in paperback with an ISBN number of 1-4165-2060-0 .
# [['1634', 'author', 'Eric Flint'], ['1634', 'ISBN_number', '``']]
# Eric Flint wrote the book `` 1634 : The Ram Rebellion '' which is available in paperback and has 512 pages .
# [['1634 : The Ram Rebellion', 'author', 'Eric Flint'],
#  ['1634 : The Ram Rebellion', 'numberOfPages', '``']]
# The abbreviation `` ACM Trans . Inf . Syst . '' is for ACM Transactions on Information Systems , which has the ISSN number 1558-2868 and the LCCN number 89646863 .
# [['ACM Transactions on Information Systems', 'ISSN_number', '``'],
#  ['ACM Transactions on Information Systems', 'LCCN_number', '89646863'],
#  ['ACM Transactions on Information Systems',
#   'abbreviation',
#   '`` ACM Trans . Inf . Syst .']]
# 89646863 is the LCCN number of ACM Transactions on Information Systems and its ISSN number is 1046-8188 . `` ACM Trans . Inf . Syst . '' is its abreviation .
# [['ACM Transactions on Information Systems',
#   'abbreviation',
#   '`` ACM Trans . Inf . Syst .'],
#  ['ACM Transactions on Information Systems', 'LCCN_number', '89646863'],
#  ['ACM Transactions on Information Systems', 'ISSN_number', '``']]
# The book `` A Fortress of Grey Ice '' by J V Jones can be found in print and the OCLC number 51969173 .
# [['A Fortress of Grey Ice', 'OCLC_number', '51969173'],
#  ['A Fortress of Grey Ice', 'mediaType', '``']]
# The book `` A Fortress of Grey Ice '' was written by J V Jones , can be found in print and has 672 pages .
# [['A Fortress of Grey Ice', 'numberOfPages', '``'],
#  ['A Fortress of Grey Ice', 'mediaType', '``']]
# The book `` A Fortress of Grey Ice '' was written by J V Jones , can be found in print and has 672 pages .
# [['A Fortress of Grey Ice', 'numberOfPages', '``'],
#  ['A Fortress of Grey Ice', 'mediaType', '``']]
# Diane Duane wrote A Wizard of Mars which is available in print and has the ISBN number `` 978-0-15-204770-2 '' .
# [['A Wizard of Mars', 'author', 'Diane Duane'],
#  ['A Wizard of Mars', 'mediaType', '``'],
#  ['A Wizard of Mars', 'ISBN_number', "`` 978-0-15-204770-2 ''"]]
# Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg ( or Abh . Math . Semin . Univ . Hambg . ) Has an ISSN number of `` 0025-5858 '' and LCCN number of 32024459 .
# [['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'ISSN_number',
#   "`` 0025-5858 ''"],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'LCCN_number',
#   '32024459'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'abbreviation',
#   '``']]
# The book `` Alcatraz Versus the Evil Librarians '' is printed with 320 pages and has an ISBN number of 0-439-92550-9 .
# [['Alcatraz Versus the Evil Librarians', 'numberOfPages', '``'],
#  ['Alcatraz Versus the Evil Librarians', 'mediaType', '``'],
#  ['Alcatraz Versus the Evil Librarians', 'ISBN_number', '``']]
# The book `` Alcatraz Versus the Evil Librarians '' is printed with 320 pages and has an ISBN number of 0-439-92550-9 .
# [['Alcatraz Versus the Evil Librarians', 'numberOfPages', '``'],
#  ['Alcatraz Versus the Evil Librarians', 'mediaType', '``'],
#  ['Alcatraz Versus the Evil Librarians', 'ISBN_number', '``']]
# The book `` Alcatraz Versus the Evil Librarians '' is printed with 320 pages and has an ISBN number of 0-439-92550-9 .
# [['Alcatraz Versus the Evil Librarians', 'numberOfPages', '``'],
#  ['Alcatraz Versus the Evil Librarians', 'mediaType', '``'],
#  ['Alcatraz Versus the Evil Librarians', 'ISBN_number', '``']]
# The American Journal of Mathematics was first published in 1878 and is abbreviated to Am . J . Math . It has the ISSN number `` 0002-9327 '' .
# [['American Journal of Mathematics', 'abbreviation', '``'],
#  ['American Journal of Mathematics', 'firstPublicationYear', '1878'],
#  ['American Journal of Mathematics', 'ISSN_number', "`` 0002-9327 ''"]]
# The nickname of the 1 Decembrie 1918 University is Uab . The latin name is `` Universitas Apulensis '' and the rector is Breaz Valer Daniel .
# [['1 Decembrie 1918 University', 'nickname', 'Uab'],
#  ['1 Decembrie 1918 University', 'rector', '``'],
#  ['1 Decembrie 1918 University', 'latinName', "`` Universitas Apulensis ''"]]
# Acharya Institute of Technology has an academic staff of 500 . It is located in India and its motto is `` Nurturing Excellence '' .
# [['Acharya Institute of Technology', 'academicStaffSize', '``'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'country', '``']]
# Acharya Institute of Technology has an academic staff of 500 . It is located in India and its motto is `` Nurturing Excellence '' .
# [['Acharya Institute of Technology', 'academicStaffSize', '``'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'country', '``']]
# Adisham Hall , located in Hautale , Sri Lanka , is in the architectural style of `` Tudor and Jacobean '' and was completed in 1931 .
# [['Adisham Hall', 'architecturalStyle', '`` Tudor and'],
#  ['Adisham Hall', 'location', '``'],
#  ['Adisham Hall', 'completionDate', '1931']]
# Asilomar Conference Grounds , constructed in 1923 and located on Asilomar Blvd in Pacific Grove , California , is designed based on the architecture style of `` Arts and Crafts Movement and American craftsman Bungalows '' .
# [['Asilomar Conference Grounds', 'location', '``'],
#  ['Asilomar Conference Grounds',
#   'architecture',
#   "`` Arts and Crafts Movement and American craftsman Bungalows ''"]]
# In the year 2000 the Acharya Institute of Technology was established in the state of Karnataka , India . The current campus address is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Director is Dr G P Prabhukumar and it is affiliated with the Visvesvaraya Technological University .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# In the year 2000 the Acharya Institute of Technology was established in the state of Karnataka , India . The current campus address is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Director is Dr G P Prabhukumar and it is affiliated with the Visvesvaraya Technological University .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# The location of the campus of the Acharya Institute of Technology in the state of Karnataka , India is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Institute , which has 700 postgraduate students , is affiliated with the Visvesvaraya Technological University and the Director is Dr G P Prabhukumar .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'numberOfPostgraduateStudents', '700'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# The location of the campus of the Acharya Institute of Technology in the state of Karnataka , India is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Institute , which has 700 postgraduate students , is affiliated with the Visvesvaraya Technological University and the Director is Dr G P Prabhukumar .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'numberOfPostgraduateStudents', '700'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# The location of the Acharya Institute of Technology is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Institute was established in 2000 in the state of Karnataka , India and has the motto `` Nurturing Excellence . It is affiliated with the Visvesvaraya Technological University .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'motto', '`` Nurturing Excellence'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# In 1928 the School of Business and Social Sciences at the Aarhus University in Denmark was established . The current Dean is Thomas Pallesen and there are 16000 students and 737 academic staff . It is affiliated with the European University Association and has the latin name of `` Universitas Aarhusiensis '' .
# [['School of Business and Social Sciences at the Aarhus University',
#   'academicStaffSize',
#   '737'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'dean',
#   '``'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'numberOfStudents',
#   '16000'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'country',
#   'Denmark'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'latinName',
#   "`` Universitas Aarhusiensis ''"],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'affiliation',
#   'European University Association'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'established',
#   '1928']]
# In 1928 the School of Business and Social Sciences at the Aarhus University was established in the city of Aarhus , Denmark . Dean Thomas Pallesen heads the School which has the Latin name of `` Universitas Aarhusiensis '' . There are 737 academic staff and it is affiliated with the European University Association .
# [['School of Business and Social Sciences at the Aarhus University',
#   'city',
#   'Aarhus'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'academicStaffSize',
#   '737'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'dean',
#   '``'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'country',
#   'Denmark'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'latinName',
#   "`` Universitas Aarhusiensis ''"],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'affiliation',
#   'European University Association'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'established',
#   '1928']]
# The Dean of the School of Business and Social Sciences at the Aarhus University in the city of Aarhus is Thomas Pallesen . The School was established in 1928 and is affiliated with the European University Association . The latin name for the School is `` Universitas Aarhusiensis '' and there are 737 academic staff and 16000 students .
# [['School of Business and Social Sciences at the Aarhus University',
#   'city',
#   'Aarhus'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'dean',
#   '``'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'numberOfStudents',
#   '16000'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'academicStaffSize',
#   '737'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'latinName',
#   "`` Universitas Aarhusiensis ''"],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'affiliation',
#   'European University Association'],
#  ['School of Business and Social Sciences at the Aarhus University',
#   'established',
#   '1928']]
# The campus address of the Acharya Institute of Technology in India is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Director of the Institute which was established in 2000 is Dr G P Prabhukumar and there are 700 postgraduate students . The Institute is affiliated with the Visvesvaraya Technological University in the city of Belgaum .
# [['Visvesvaraya Technological University', 'city', 'Belgaum'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'numberOfPostgraduateStudents', '700'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# The campus address of the Acharya Institute of Technology in India is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Director of the Institute which was established in 2000 is Dr G P Prabhukumar and there are 700 postgraduate students . The Institute is affiliated with the Visvesvaraya Technological University in the city of Belgaum .
# [['Visvesvaraya Technological University', 'city', 'Belgaum'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'numberOfPostgraduateStudents', '700'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# Baku Turkish Martyrs ' Memorial , made from red granite and white marble , is dedicated to the Ottoman Army soldiers killed in the Battle of Baku , Azerbaijan . The memorial ( native name `` Türk Sehitleri Aniti '' ) was designed by Huseyin Butuner and Hilmi Guner . Artur Rasizade is the leader ( official title President ) of Azerbaijan .
# [['Azerbaijan', 'leader', 'Artur Rasizade'],
#  ["Baku Turkish Martyrs ' Memorial", 'material', '``'],
#  ["Baku Turkish Martyrs ' Memorial", 'dedicatedTo', '``'],
#  ["Baku Turkish Martyrs ' Memorial", 'location', 'Azerbaijan'],
#  ["Baku Turkish Martyrs ' Memorial", 'nativeName', '`` Türk'],
#  ["Baku Turkish Martyrs ' Memorial", 'designer', '``']]
# Baku Turkish Martyrs ' Memorial , made from red granite and white marble , is dedicated to the Ottoman Army soldiers killed in the Battle of Baku , Azerbaijan . The memorial ( native name `` Türk Sehitleri Aniti '' ) was designed by Huseyin Butuner and Hilmi Guner . Artur Rasizade is the leader ( official title President ) of Azerbaijan .
# [['Azerbaijan', 'leader', 'Artur Rasizade'],
#  ["Baku Turkish Martyrs ' Memorial", 'material', '``'],
#  ["Baku Turkish Martyrs ' Memorial", 'dedicatedTo', '``'],
#  ["Baku Turkish Martyrs ' Memorial", 'location', 'Azerbaijan'],
#  ["Baku Turkish Martyrs ' Memorial", 'nativeName', '`` Türk'],
#  ["Baku Turkish Martyrs ' Memorial", 'designer', '``']]
# Baku Turkish Martyrs ' Memorial , made from red granite and white marble , is dedicated to the Ottoman Army soldiers killed in the Battle of Baku , Azerbaijan . The memorial ( native name `` Türk Sehitleri Aniti '' ) was designed by Huseyin Butuner and Hilmi Guner . Artur Rasizade is the leader ( official title President ) of Azerbaijan .
# [['Azerbaijan', 'leader', 'Artur Rasizade'],
#  ["Baku Turkish Martyrs ' Memorial", 'material', '``'],
#  ["Baku Turkish Martyrs ' Memorial", 'dedicatedTo', '``'],
#  ["Baku Turkish Martyrs ' Memorial", 'location', 'Azerbaijan'],
#  ["Baku Turkish Martyrs ' Memorial", 'nativeName', '`` Türk'],
#  ["Baku Turkish Martyrs ' Memorial", 'designer', '``']]
# Eric Flint wrote the book `` 1634 : The Ram Rebellion '' and is 512 pages long . It can be found in hardcover and has the ISBN number 1-4165-2060-0 .
# [['1634 : The Ram Rebellion', 'author', 'Eric Flint'],
#  ['1634 : The Ram Rebellion', 'numberOfPages', '``'],
#  ['1634 : The Ram Rebellion', 'ISBN_number', '``']]
# Eric Flint wrote the book `` 1634 : The Ram Rebellion '' and is 512 pages long . It can be found in hardcover and has the ISBN number 1-4165-2060-0 .
# [['1634 : The Ram Rebellion', 'author', 'Eric Flint'],
#  ['1634 : The Ram Rebellion', 'numberOfPages', '``'],
#  ['1634 : The Ram Rebellion', 'ISBN_number', '``']]
# ACM Transactions on Information Systems ( abbreviation : ACM Trans . Inf . Syst . ) has the LCCN number 89646863 and the ISSN number 1558-2868 . The CODEN code for ACM Transactions on Information Systems is `` ATISET '' .
# [['ACM Transactions on Information Systems', 'ISSN_number', '``'],
#  ['ACM Transactions on Information Systems', 'LCCN_number', '89646863'],
#  ['ACM Transactions on Information Systems', 'abbreviation', '``'],
#  ['ACM Transactions on Information Systems', 'CODEN_code', "`` ATISET ''"]]
# ACM Transactions on Information Systems ( abbreviation : ACM Trans . Inf . Syst . ) has the LCCN number 89646863 and the ISSN number 1558-2868 . The CODEN code for ACM Transactions on Information Systems is `` ATISET '' .
# [['ACM Transactions on Information Systems', 'ISSN_number', '``'],
#  ['ACM Transactions on Information Systems', 'LCCN_number', '89646863'],
#  ['ACM Transactions on Information Systems', 'abbreviation', '``'],
#  ['ACM Transactions on Information Systems', 'CODEN_code', "`` ATISET ''"]]
# `` Abh.Math.Semin.Univ.Hambg '' is the abbreviation for Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg . Their ISSN number is 0025-5858 , their LCCN number is 32024459 and their CODEN code is AMHAAJ .
# [['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'ISSN_number',
#   '``'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'LCCN_number',
#   '32024459'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'abbreviation',
#   '``'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'CODEN_code',
#   '``']]
# `` Abh.Math.Semin.Univ.Hambg '' is the abbreviation for Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg . Their ISSN number is 0025-5858 , their LCCN number is 32024459 and their CODEN code is AMHAAJ .
# [['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'ISSN_number',
#   '``'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'LCCN_number',
#   '32024459'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'abbreviation',
#   '``'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'CODEN_code',
#   '``']]
# `` Abh.Math.Semin.Univ.Hambg '' is the abbreviation for Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg . Their ISSN number is 0025-5858 , their LCCN number is 32024459 and their CODEN code is AMHAAJ .
# [['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'ISSN_number',
#   '``'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'LCCN_number',
#   '32024459'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'abbreviation',
#   '``'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'CODEN_code',
#   '``']]
# The Acta Mathematica Hungarica ( abbrv . Acta Math . Hungar ) has the CODEN code `` AMAHE9 '' . It 's ISSN and LCCN numbers are 0236-5294 and 83646315 respectively .
# [['Acta Mathematica Hungarica', 'ISSN_number', '``'],
#  ['Acta Mathematica Hungarica', 'LCCN_number', '83646315'],
#  ['Acta Mathematica Hungarica', 'abbreviation', '``'],
#  ['Acta Mathematica Hungarica', 'CODEN_code', "`` AMAHE9 ''"]]
# The Acta Mathematica Hungarica ( abbrv . Acta Math . Hungar ) has the CODEN code `` AMAHE9 '' . It 's ISSN and LCCN numbers are 0236-5294 and 83646315 respectively .
# [['Acta Mathematica Hungarica', 'ISSN_number', '``'],
#  ['Acta Mathematica Hungarica', 'LCCN_number', '83646315'],
#  ['Acta Mathematica Hungarica', 'abbreviation', '``'],
#  ['Acta Mathematica Hungarica', 'CODEN_code', "`` AMAHE9 ''"]]
# Acta Mathematica Hungarica is abbreviated as `` Acta Math . Hungar '' . The ISSN # is : 1588-2632 ; LCCN # : 83646315 and code AMAHE9 .
# [['Acta Mathematica Hungarica', 'ISSN_number', '``'],
#  ['Acta Mathematica Hungarica', 'LCCN_number', '83646315'],
#  ['Acta Mathematica Hungarica', 'abbreviation', '`` Acta Math . Hungar'],
#  ['Acta Mathematica Hungarica', 'CODEN_code', '``']]
# Acta Mathematica Hungarica is abbreviated as `` Acta Math . Hungar '' . The ISSN # is : 1588-2632 ; LCCN # : 83646315 and code AMAHE9 .
# [['Acta Mathematica Hungarica', 'ISSN_number', '``'],
#  ['Acta Mathematica Hungarica', 'LCCN_number', '83646315'],
#  ['Acta Mathematica Hungarica', 'abbreviation', '`` Acta Math . Hungar'],
#  ['Acta Mathematica Hungarica', 'CODEN_code', '``']]
# 83646315 is the LCCN number for Acta Mathematica Hungarica and the ISSN number is 1588-2632 . Its bbreviation is `` Acta Math . Hungar . '' and its discipline is Math .
# [['Acta Mathematica Hungarica', 'LCCN_number', '83646315'],
#  ['Acta Mathematica Hungarica', 'abbreviation', '`` Acta Math . Hungar .'],
#  ['Acta Mathematica Hungarica', 'ISSN_number', '``']]
# Acta Palaeontologica Polonica , ISSN number is `` 0567-7920 '' , LCCN number of 60040714 , was published by the Polish Academy of Sciences and is known as Acta Palaeontol . Pol .
# [['Acta Palaeontologica Polonica', 'publisher', 'Polish Academy of Sciences'],
#  ['Acta Palaeontologica Polonica', 'ISSN_number', "`` 0567-7920 ''"],
#  ['Acta Palaeontologica Polonica', 'LCCN_number', '60040714'],
#  ['Acta Palaeontologica Polonica', 'abbreviation', '``']]
# Acta Palaeontologica Polonica was published by the Polish Academy of Sciences and is abbreviated Acta Palaeontol . Pol . . The CODEN code is `` APGPAC '' and the LCCN number is 60040714 .
# [['Acta Palaeontologica Polonica', 'publisher', 'Polish Academy of Sciences'],
#  ['Acta Palaeontologica Polonica', 'LCCN_number', '60040714'],
#  ['Acta Palaeontologica Polonica', 'abbreviation', '``'],
#  ['Acta Palaeontologica Polonica', 'CODEN_code', "`` APGPAC ''"]]
# The Addiction journal is published by Wiley-Blackwell on behalf of the Society for the Study of Addiction and has the ISSN number 1360-0443 . It has the abbreviation of `` Addiction '' and the LCCN number 93645978 .
# [['Addiction', 'ISSN_number', '``'],
#  ['Addiction', 'LCCN_number', '93645978'],
#  ['Addiction', 'abbreviation', "`` Addiction ''"],
#  ['Addiction', 'publisher', '``']]
# The Addiction journal is published by Wiley-Blackwell on behalf of the Society for the Study of Addiction and has the ISSN number 1360-0443 . It has the abbreviation of `` Addiction '' and the LCCN number 93645978 .
# [['Addiction', 'ISSN_number', '``'],
#  ['Addiction', 'LCCN_number', '93645978'],
#  ['Addiction', 'abbreviation', "`` Addiction ''"],
#  ['Addiction', 'publisher', '``']]
# Administrative Science Quarterly is published by SAGE Publications for the Samuel Curtis Johnson Graduate School of Management , Cornell University . It is abbreviated to Admin . Sci . Q . Its ISSN number is `` 0001-8392 '' and LLCN number is 57059226 .
# [['Administrative Science Quarterly', 'abbreviation', '``'],
#  ['Administrative Science Quarterly', 'ISSN_number', "`` 0001-8392 ''"],
#  ['Administrative Science Quarterly', 'LCCN_number', '57059226'],
#  ['Administrative Science Quarterly', 'publisher', '``']]
# Administrative Science Quarterly is published by SAGE Publications for the Samuel Curtis Johnson Graduate School of Management , Cornell University . It is abbreviated to Admin . Sci . Q . Its ISSN number is `` 0001-8392 '' and LLCN number is 57059226 .
# [['Administrative Science Quarterly', 'abbreviation', '``'],
#  ['Administrative Science Quarterly', 'ISSN_number', "`` 0001-8392 ''"],
#  ['Administrative Science Quarterly', 'LCCN_number', '57059226'],
#  ['Administrative Science Quarterly', 'publisher', '``']]
# Administrative Science Quarterly was published by Cornell University and has the abbreviation of Admin . Sci . Q. . It has the ISSN number `` 0001-8392 '' and the LCCN number of 57059226 .
# [['Administrative Science Quarterly', 'publisher', 'Cornell University'],
#  ['Administrative Science Quarterly', 'abbreviation', '``'],
#  ['Administrative Science Quarterly', 'ISSN_number', "`` 0001-8392 ''"],
#  ['Administrative Science Quarterly', 'LCCN_number', '57059226']]
# The American Journal of Mathematics was first published in 1878 and is also known by the abbreviated title of Am . J . Math . It has the ISSN number `` 0002-9327 '' and comes under the discipline of Math .
# [['American Journal of Mathematics', 'academicDiscipline', 'Mathematics'],
#  ['American Journal of Mathematics', 'firstPublicationYear', '1878'],
#  ['American Journal of Mathematics', 'abbreviation', '``'],
#  ['American Journal of Mathematics', 'ISSN_number', "`` 0002-9327 ''"]]
# The fried chicken dish Ayam penyet can be found all over Indonesia , Malaysia and Singapore . The chicken is `` squeezed '' or `` smashed '' and served with sambal .
# [['Ayam penyet', 'region', '``'],
#  ['Ayam penyet', 'mainIngredients', '``'],
#  ['Ayam penyet', 'country', 'Indonesia']]
# The fried chicken dish Ayam penyet can be found all over Indonesia , Malaysia and Singapore . The chicken is `` squeezed '' or `` smashed '' and served with sambal .
# [['Ayam penyet', 'region', '``'],
#  ['Ayam penyet', 'mainIngredients', '``'],
#  ['Ayam penyet', 'country', 'Indonesia']]
# Ayam penyet is a dish from the region of Singapore and Indonesia . The main ingredients of Ayam penyet are `` squeezed '' or `` smashed '' chicken served with sambal . It also has fried chicken in it .
# [['Ayam penyet', 'region', 'Singapore'],
#  ['Ayam penyet', 'mainIngredients', '``'],
#  ['Ayam penyet', 'country', 'Indonesia']]
# Batagor comes from the country of Indonesia . It is made using fried fish dumpling with tofu and vegetables in Peanut sauce and should be served `` hot '' .
# [['Batagor', 'country', 'Indonesia'],
#  ['Batagor', 'ingredient', 'Peanut sauce'],
#  ['Batagor', 'mainIngredients', '``'],
#  ['Batagor', 'servingTemperature', "`` hot ''"]]
# Agra Airport , with the ICAO location identifier of `` VIAG '' , is located in Uttar Pradesh . The IATA I.D of the airport is AGR and the operating organisation is the Airports Authority of India .
# [['Agra Airport', 'location', 'Uttar Pradesh'],
#  ['Agra Airport', 'IATA_Location_Identifier', '``'],
#  ['Agra Airport', 'ICAO_Location_Identifier', "`` VIAG ''"],
#  ['Agra Airport', 'operatingOrganisation', 'Airports Authority of India']]
# A.F.C . Blackpool 's has 1500 members and their ground is The Mechanics . A.F.C . Blackpool 's full name is `` Association Football Club Blackpool '' and they played in season 2014 .
# [['A.F.C . Blackpool', 'ground', '``'],
#  ['A.F.C . Blackpool', 'season', '2014'],
#  ['A.F.C . Blackpool', 'numberOfMembers', '1500'],
#  ['A.F.C . Blackpool', 'fullname', "`` Association Football Club Blackpool ''"]]
# Agremiação Sportiva Arapiraquense 's full name is `` Agremiação Sportiva Arapiraquense '' although their nickname is Alvinegro . The club has 17000 members and were in Campeonato Brasileiro Serie C in 2015 .
# [['Agremiação Sportiva Arapiraquense', 'nickname', '``'],
#  ['Agremiação Sportiva Arapiraquense', 'numberOfMembers', '17000'],
#  ['Agremiação Sportiva Arapiraquense', 'season', '2015'],
#  ['Agremiação Sportiva Arapiraquense',
#   'fullname',
#   "`` Agremiação Sportiva Arapiraquense ''"]]
# Agremiação Sportiva Arapiraquense ( which is the club 's full name ) played in the 2015 season . They have 17000 members and the nickname `` Alvinegro '' .
# [['Agremiação Sportiva Arapiraquense', 'nickname', '``'],
#  ['Agremiação Sportiva Arapiraquense', 'season', '2015'],
#  ['Agremiação Sportiva Arapiraquense', 'numberOfMembers', '17000'],
#  ['Agremiação Sportiva Arapiraquense', 'fullname', '``']]
# Agremiação Sportiva Arapiraquense ( which is the club 's full name ) played in the 2015 season . They have 17000 members and the nickname `` Alvinegro '' .
# [['Agremiação Sportiva Arapiraquense', 'nickname', '``'],
#  ['Agremiação Sportiva Arapiraquense', 'season', '2015'],
#  ['Agremiação Sportiva Arapiraquense', 'numberOfMembers', '17000'],
#  ['Agremiação Sportiva Arapiraquense', 'fullname', '``']]
# Construction of Adisham Hall , Haputale , designed in the `` Tudor Revival '' style , began in 1927 and was finished in 1931 .
# [['Adisham Hall', 'architecturalStyle', 'Tudor Revival'],
#  ['Adisham Hall', 'completionDate', '1931'],
#  ['Adisham Hall', 'buildingStartDate', '``'],
#  ['Adisham Hall', 'location', 'Haputale']]
# Asilomar Conference Grounds which are designed based on the architecture style of `` Arts and Crafts Movement and American craftsman Bungalows '' and have the reference number in the the National Register of Historic Places of 87000823 , were constructed in 1913 at Asilomar Blvd. , Pacific Grove , California .
# [['Asilomar Conference Grounds', 'location', '``'],
#  ['Asilomar Conference Grounds',
#   'ReferenceNumber in the National Register of Historic Places',
#   '``'],
#  ['Asilomar Conference Grounds', 'yearOfConstruction', '1913'],
#  ['Asilomar Conference Grounds',
#   'architecture',
#   "`` Arts and Crafts Movement and American craftsman Bungalows ''"]]
# Asilomar Conference Grounds which are designed based on the architecture style of `` Arts and Crafts Movement and American craftsman Bungalows '' and have the reference number in the the National Register of Historic Places of 87000823 , were constructed in 1913 at Asilomar Blvd. , Pacific Grove , California .
# [['Asilomar Conference Grounds', 'location', '``'],
#  ['Asilomar Conference Grounds',
#   'ReferenceNumber in the National Register of Historic Places',
#   '``'],
#  ['Asilomar Conference Grounds', 'yearOfConstruction', '1913'],
#  ['Asilomar Conference Grounds',
#   'architecture',
#   "`` Arts and Crafts Movement and American craftsman Bungalows ''"]]
# Asilomar Conference Grounds are located in Pacific Grove , California , was constructed in 1913 , has the reference number 87000823 in the National Register of Historic Places and architecturally is of the `` Arts and Crafts Movement and American Craftsman Bungalows '' .
# [['Asilomar Conference Grounds', 'location', 'Pacific Grove , California'],
#  ['Asilomar Conference Grounds',
#   'ReferenceNumber in the National Register of Historic Places',
#   '``'],
#  ['Asilomar Conference Grounds', 'yearOfConstruction', '1913'],
#  ['Asilomar Conference Grounds',
#   'architecture',
#   '`` Arts and Crafts Movement and American']]
# Located in Pacific Grove , California , Asilomar Conference Grounds were constructed in 1913 , added to the National Register of Historic Places on 27nd February 1987 and is in the architectural style of the `` Arts and Crafts Movement and American Craftsman Bungalows '' .
# [['Asilomar Conference Grounds', 'location', 'Pacific Grove , California'],
#  ['Asilomar Conference Grounds',
#   'added to the National Register of Historic Places',
#   '``'],
#  ['Asilomar Conference Grounds', 'yearOfConstruction', '1913'],
#  ['Asilomar Conference Grounds',
#   'architecture',
#   '`` Arts and Crafts Movement and American']]
# The rector of the 1 Decembrie 1918 University in the state of Alba , Romania is Breaz Valer Daniel . The latin name of the university is `` Universitas Apulensis '' .
# [['1 Decembrie 1918 University', 'rector', '``'],
#  ['1 Decembrie 1918 University', 'latinName', "`` Universitas Apulensis ''"],
#  ['1 Decembrie 1918 University', 'country', 'Romania'],
#  ['1 Decembrie 1918 University', 'state', 'Alba']]
# The 1 Decembrie 1918 University is located in Alba Iulia , Alba , Romania . Its Latun name is `` Universitas Apulensis '' and its nickname is `` Uab '' . Its rectore is Breaz Valer Daniel .
# [['1 Decembrie 1918 University', 'nickname', 'Uab'],
#  ['1 Decembrie 1918 University', 'rector', '``'],
#  ['1 Decembrie 1918 University', 'city', 'Alba Iulia'],
#  ['1 Decembrie 1918 University', 'latinName', "`` Universitas Apulensis ''"],
#  ['1 Decembrie 1918 University', 'country', 'Romania'],
#  ['1 Decembrie 1918 University', 'state', 'Alba']]
# The Acharya Institute of Technology 's campus is in Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore , India , 560090 . Its director is Dr G.P . Prabhukumar and its motto is `` Nurturing Excellence '' . It is affiliated with the Visvesvaraya Technological University .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'campus', '``'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# The Acharya Institute of Technology 's campus is in Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore , India , 560090 . Its director is Dr G.P . Prabhukumar and its motto is `` Nurturing Excellence '' . It is affiliated with the Visvesvaraya Technological University .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'campus', '``'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# The Acharya Institute of Technology 's campus is in Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore , India , 560090 . Its director is Dr G.P . Prabhukumar and its motto is `` Nurturing Excellence '' . It is affiliated with the Visvesvaraya Technological University .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'campus', '``'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# 1634 : The Bavarian Crisis , written by Virginia DeMarce and Eric Flint , can be located by it 's ISBN number `` 978-1-4165-4253-7 '' .
# [['1634 : The Bavarian Crisis', 'ISBN_number', "`` 978-1-4165-4253-7 ''"],
#  ['1634 : The Bavarian Crisis', 'author', '``']]
# `` A Glastonbury Romance `` which has 1174 pages can be found in hardcover .
# [['A Glastonbury Romance', 'numberOfPages', '``']]
# The 388-page `` A Severed Wasp '' has an ISBN number of `` 0-374-26131-8 .
# [['A Severed Wasp', 'numberOfPages', '``'],
#  ['A Severed Wasp', 'ISBN_number', '`` 0-374-26131-8']]
# `` Abh.Math.Semin.Univ.Hambg '' is the abbreviation for Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg and is concerned with the academic discipline of Pure Mathematics .
# [['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'academicDiscipline',
#   'Pure'],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'abbreviation',
#   '``']]
# Garth Nix is the author of `` Above the Veil , '' ISBN number 0-439-17685-9 .
# [['Above the Veil', 'author', 'Garth Nix'],
#  ['Above the Veil', 'ISBN_number', '``']]
# Acta Palaeontologica Polonica ( abbreviated to Acta Palaeontol . Pol . ) has a CODEN code of `` APGPAC '' .
# [['Acta Palaeontologica Polonica', 'abbreviation', '``'],
#  ['Acta Palaeontologica Polonica', 'CODEN_code', "`` APGPAC ''"]]
# Aenir is available in print and has the ISBN number of `` 0-439-17684-0 '' .
# [['Aenir', 'mediaType', '``'], ['Aenir', 'ISBN_number', "`` 0-439-17684-0 ''"]]
# The motto of the Acharya Institute of Technology is `` Nurturing Excellence '' and there is an academic staff of 500 .
# [['Acharya Institute of Technology', 'academicStaffSize', '``'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"]]
# The book `` A Fortress of Grey Ice '' can be found in print .
# [['A Fortress of Grey Ice', 'mediaType', '``']]
# The Library of Congress Classification of `` A Glastonbury Romance '' is PR6031 .0867 .
# [['A Glastonbury Romance', 'LibraryofCongressClassification', '``']]
# PS3523.E55 S4 1982 is the Library of Congress Classification of `` A Severed Wasp '' .
# [['A Severed Wasp', 'LibraryofCongressClassification', '``']]
# `` Abh.Math.Semin.Univ.Hambg '' is the abbreviation for Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg .
# [['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'abbreviation',
#   '``']]
# The book `` Alcatraz Versus the Evil Librarians is in print .
# [['Alcatraz Versus the Evil Librarians', 'mediaType', '``']]
# The main ingredients of Ayam penyet are `` squeezed '' or `` smashed '' chicken served with sambal .
# [['Ayam penyet', 'mainIngredients', '``']]
# Ayam Penyet is a Malaysian dish including the main ingredients of `` squeezed '' or `` smashed '' chicken served with sambal . The dish can be found in Java where the Banyumasan people are an ethnic group .
# [['Java', 'ethnicGroup', 'Banyumasan people'],
#  ['Ayam', 'mainIngredients', '``'],
#  ['Ayam', 'country', 'Java']]
# The Javanese people are an ethnic group of Java , where the food Ayam penyet can be found . The dish , which has the main ingredients `` squeezed '' or `` smashed '' fried chicken served with sambal , can be found nationwide and also in Malaysia and Singapore .
# [['Java', 'ethnicGroup', 'Javanese people'],
#  ['Ayam penyet', 'mainIngredients', '``'],
#  ['Ayam penyet', 'region', '``'],
#  ['Ayam penyet', 'country', 'Java']]
# The Javanese people are an ethnic group of Java , where the food Ayam penyet can be found . The dish , which has the main ingredients `` squeezed '' or `` smashed '' fried chicken served with sambal , can be found nationwide and also in Malaysia and Singapore .
# [['Java', 'ethnicGroup', 'Javanese people'],
#  ['Ayam penyet', 'mainIngredients', '``'],
#  ['Ayam penyet', 'region', '``'],
#  ['Ayam penyet', 'country', 'Java']]
# Acta Palaeontologica Polonica was published by the Polish Academy of Sciences and is abbreviated to Acta Palaeontol . Pol . . It is identified by the ISSN number of `` 1732-2421 '' and the LCCN number of 60040714 . It also has the CODEN code of `` APGPAC '' .
# [['Acta Palaeontologica Polonica', 'publisher', 'Polish Academy of Sciences'],
#  ['Acta Palaeontologica Polonica', 'ISSN_number', "`` 1732-2421 ''"],
#  ['Acta Palaeontologica Polonica', 'LCCN_number', '60040714'],
#  ['Acta Palaeontologica Polonica', 'abbreviation', '``'],
#  ['Acta Palaeontologica Polonica', 'CODEN_code', "`` APGPAC ''"]]
# In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 is the location of the Acharya Institute of Technology established in the state of Karnataka , India in the year 2000 . The Institute , whose motto is `` Nurturing Excellence '' is affiliated with the Visvesvaraya Technological University in the city of Belgaum .
# [['Visvesvaraya Technological University', 'city', 'Belgaum'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'campus', '``'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 is the location of the Acharya Institute of Technology established in the state of Karnataka , India in the year 2000 . The Institute , whose motto is `` Nurturing Excellence '' is affiliated with the Visvesvaraya Technological University in the city of Belgaum .
# [['Visvesvaraya Technological University', 'city', 'Belgaum'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'campus', '``'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# Ayam penyet , which is from Java , is a dish from the region of Singapore . The main ingredients of ayma penyet , of which fried chicken is one , are `` squeezed '' or `` smashed '' chicken served with sambal .
# [['Ayam penyet', 'region', 'Singapore'],
#  ['Ayam penyet', 'country', 'Java'],
#  ['Ayam penyet', 'mainIngredients', '``']]
# Jorge Humberto Rodríguez manages the A.D. Isidro Metapan , is located in Metapán , El Salvado , has 10000 members , and full name is `` Asociación Deportiva '' .
# [['A.D. Isidro', 'manager', 'Jorge Humberto Rodríguez'],
#  ['A.D. Isidro', 'ground', '``'],
#  ['A.D. Isidro', 'numberOfMembers', '10000'],
#  ['A.D. Isidro', 'fullname', "`` Asociación Deportiva ''"]]
# Paul Gustavson is the creator of `` The Arrow '' , otherwise known as Ralph Payne .
# [['The Arrow', 'alternativeName', '``'],
#  ['The Arrow', 'creator', 'Paul Gustavson']]
# Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg can be located by the ISSN number `` 0025-5858 '' and has the abbreviation Abh . Math . Semin . Univ . Hambg .
# [['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'ISSN_number',
#   "`` 0025-5858 ''"],
#  ['Abhandlungen aus dem Mathematischen Seminar der Universität Hamburg',
#   'abbreviation',
#   '``']]
# Alan B Miller Hall ( which was inaugurated on 2009-10-02 ) has the address `` 101 Ukrop Way '' .
# [['Alan', 'inaugurationDate', '``'], ['Alan', 'address', "`` 101 Ukrop Way ''"]]
# The `` Associazione Sportiva Roma S.p.A. '' is the non-abbreviated name of A.S. Roma which has 70634 members and a home ground in Rome , Italy .
# [['A.S. Roma', 'fullname', "`` Associazione Sportiva Roma S.p.A. ''"],
#  ['A.S. Roma', 'ground', '``'],
#  ['A.S. Roma', 'numberOfMembers', '70634']]
# Angola International Airport is located at Ícolo e Bengo in Angola and the runway is named `` south runway '' .
# [['Angola International Airport', 'location', 'Ícolo e Bengo'],
#  ['Ícolo e Bengo', 'country', 'Angola'],
#  ['Angola International Airport', 'runwayName', '``']]
# The Acharya Institute of Technology is located in Bangalore , India and its motto is : `` Nurturing Excellence '' .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'country', '``']]
# 1634 : The Bavarian Crisis can be located by it 's ISBN number `` 978-1-4165-4253-7 '' . It is written by Virginia DeMarce and Eric Flint and was put in print .
# [['1634 : The Bavarian Crisis', 'ISBN_number', "`` 978-1-4165-4253-7 ''"],
#  ['1634 : The Bavarian Crisis', 'author', '``'],
#  ['1634 : The Bavarian Crisis', 'mediaType', '``']]
# 1634 : The Bavarian Crisis can be located by it 's ISBN number `` 978-1-4165-4253-7 '' . It is written by Virginia DeMarce and Eric Flint and was put in print .
# [['1634 : The Bavarian Crisis', 'ISBN_number', "`` 978-1-4165-4253-7 ''"],
#  ['1634 : The Bavarian Crisis', 'author', '``'],
#  ['1634 : The Bavarian Crisis', 'mediaType', '``']]
# A Severed Wasp has an ISBN number of `` 0-374-26131-8 '' , 388 pages and can be found in print .
# [['A Severed Wasp', 'numberOfPages', '``'],
#  ['A Severed Wasp', 'mediaType', '``'],
#  ['A Severed Wasp', 'ISBN_number', "`` 0-374-26131-8 ''"]]
# A Severed Wasp has an ISBN number of `` 0-374-26131-8 '' , 388 pages and can be found in print .
# [['A Severed Wasp', 'numberOfPages', '``'],
#  ['A Severed Wasp', 'mediaType', '``'],
#  ['A Severed Wasp', 'ISBN_number', "`` 0-374-26131-8 ''"]]
# The Acta Mathematica Hungarica ISSN number is `` 0236-5294 '' and the abbreviation is Acta Math . Hungar . It comes under the academic discipline of Math .
# [['Acta Mathematica Hungarica', 'abbreviation', '``'],
#  ['Acta Mathematica Hungarica', 'ISSN_number', "`` 0236-5294 ''"]]
# Addiction is the abbreviated version of the `` Addiction Journal '' which has the ISSN number 0965-2140 .
# [['Addiction', 'academicDiscipline', 'Addiction'],
#  ['Addiction', 'abbreviation', '`` Addiction'],
#  ['Addiction', 'ISSN_number', '``']]
# Aenir has the ISBN number of `` 0-439-17684-0 '' , it was written by Garth Nix and was produced in print .
# [['Aenir', 'author', 'Garth Nix'],
#  ['Aenir', 'mediaType', '``'],
#  ['Aenir', 'ISBN_number', "`` 0-439-17684-0 ''"]]
# In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 is the location of the Acharya Institute of Technology in India which is affiliated with the Visvesvaraya Technological University . The motto of the Institute which was established in the year 2000 is `` Nurturing Excellence '' and there are 700 postgraduate students .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'numberOfPostgraduateStudents', '700'],
#  ['Acharya Institute of Technology', 'campus', '``'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 is the location of the Acharya Institute of Technology in India which is affiliated with the Visvesvaraya Technological University . The motto of the Institute which was established in the year 2000 is `` Nurturing Excellence '' and there are 700 postgraduate students .
# [['Acharya Institute of Technology', 'city', 'Bangalore'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'motto', "`` Nurturing Excellence ''"],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology', 'numberOfPostgraduateStudents', '700'],
#  ['Acharya Institute of Technology', 'campus', '``'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# In the year 2000 the Acharya Institute of Technology was established in the state of Karnataka , India . The current location is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Director is Dr G P Prabhukumar and it is affiliated with the Visvesvaraya Technological University in the city of Belgaum .
# [['Visvesvaraya Technological University', 'city', 'Belgaum'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# In the year 2000 the Acharya Institute of Technology was established in the state of Karnataka , India . The current location is `` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , Hessarghatta Main Road , Bangalore – 560090 . '' The Director is Dr G P Prabhukumar and it is affiliated with the Visvesvaraya Technological University in the city of Belgaum .
# [['Visvesvaraya Technological University', 'city', 'Belgaum'],
#  ['Acharya Institute of Technology', 'director', '``'],
#  ['Acharya Institute of Technology', 'established', '2000'],
#  ['Acharya Institute of Technology', 'state', 'Karnataka'],
#  ['Acharya Institute of Technology', 'country', '``'],
#  ['Acharya Institute of Technology',
#   'campus',
#   '`` In Soldevanahalli , Acharya Dr. Sarvapalli Radhakrishnan Road , '
#   'Hessarghatta Main Road , Bangalore – 560090 .'],
#  ['Acharya Institute of Technology',
#   'affiliation',
#   'Visvesvaraya Technological University']]
# A Severed Wasp was published in hardback and has 388 pages . The OCLC number of A Severed Wasp is 8805735 and the ISBN number of `` 0-374-26131-8 '' .
# [['A Severed Wasp', 'numberOfPages', '``'],
#  ['A Severed Wasp', 'OCLC_number', '8805735'],
#  ['A Severed Wasp', 'ISBN_number', "`` 0-374-26131-8 ''"]]
# The Addiction journal UNK the UNK of Addiction and has the LCCN number 93645978 . The abbreviated name is `` Addiction '' and the ISSN number is 1360-0443 .
# [['Addiction', 'academicDiscipline', 'Addiction'],
#  ['Addiction', 'LCCN_number', '93645978'],
#  ['Addiction', 'abbreviation', "`` Addiction ''"],
#  ['Addiction', 'ISSN_number', '``']]
# The Administrative Science Quarterly has a Coden code of `` ASCQAG '' and the abbreviation of Admin.Sci.Q .
# [['Administrative Science Quarterly', 'CODEN_code', "`` ASCQAG ''"],
#  ['Administrative Science Quarterly', 'abbreviation', '``']]
# Ayam penyet is a food found in Java and the main ingredients are `` squeezed '' or `` smashed '' chicken served with sambal .
# [['Ayam penyet', 'country', 'Java'], ['Ayam penyet', 'mainIngredients', '``']]
# The All India Council for Technical Education UNK the Acharya Institute of Technology the status of `` Technical Campus '' . The official school colours are blue , white and orange .
# [['Acharya Institute of Technology', 'officialSchoolColour', '``'],
#  ['Acharya Institute of Technology',
#   "was given the 'Technical Campus' status by",
#   'All India Council for Technical Education']]

# %% [markdown]
# # Raw NYT

# %%
nyt_data_dir = "../ori_data/nyt"
nyt_train_data_path = os.path.join(nyt_data_dir, "raw_train.json")
nyt_valid_data_path = os.path.join(nyt_data_dir, "raw_valid.json")
nyt_test_data_path = os.path.join(nyt_data_dir, "raw_test.json")

# %%
def get_data(path):
    with open(path, "r", encoding = "utf-8") as file:
        data = [json.loads(line) for line in file]
    return data

# %%
nyt_train_data = get_data(nyt_train_data_path)
nyt_valid_data = get_data(nyt_valid_data_path)
nyt_test_data = get_data(nyt_test_data_path)

# %%
def remove_stress_mark(text):
    text = "".join([c for c in unicodedata.normalize("NFD", text) if unicodedata.category(c) != "Mn"])
    return text

# %%
for sample in tqdm(nyt_train_data + nyt_valid_data + nyt_test_data):
    # remove stress marks
    for rel in sample["relationMentions"]:
        rel["em1Text"] = remove_stress_mark(rel["em1Text"])
        rel["em2Text"] = remove_stress_mark(rel["em2Text"])
# Out:
# 100%|██████████| 66196/66196 [00:01<00:00, 48675.62it/s]

# %%
# fix a bad sample
for sample in tqdm(nyt_train_data + nyt_valid_data + nyt_test_data):
    if "XXXXXXXXXX" in sample["sentText"]:
        sample["sentText"] = re.sub("X+", "", sample["sentText"])
# Out:
# 100%|██████████| 66196/66196 [00:00<00:00, 549415.74it/s]

# %%
# Output to Disk
train_data_path = os.path.join(nyt_data_dir, "train_data.json")
valid_data_path = os.path.join(nyt_data_dir, "valid_data.json")
test_data_dir = os.path.join(nyt_data_dir, "test_data")
if not os.path.exists(test_data_dir):
    os.mkdir(test_data_dir)
test_data_path = os.path.join(test_data_dir, "test_data.json")

json.dump(nyt_train_data, open(train_data_path, "w", encoding = "utf-8"), ensure_ascii = False)
json.dump(nyt_valid_data, open(valid_data_path, "w", encoding = "utf-8"), ensure_ascii = False)
json.dump(nyt_test_data, open(test_data_path, "w", encoding = "utf-8"), ensure_ascii = False)
